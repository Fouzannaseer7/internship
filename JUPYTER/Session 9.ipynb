# %% [raw]
# ✅ List, Tuple, Dictionary & Set Quiz:

# %% [raw]
# Instructions: Each question has one correct answer. Answers are given below.

# %% [raw]
# 📝 Section A: Lists:

# %% [raw]
# 1.What will be the output of this code?
#
# a = [1, 2, 3]
# a.append([4, 5])
# print(a)
#
# a) [1, 2, 3, 4, 5]
# b) [1, 2, 3, [4, 5]]
# c) [1, 2, 3, (4, 5)]
# d) Error

# %% [raw]
# 2.Which method removes the first matching value from a list?
#
# a) remove()
# b) delete()
# c) pop()
# d) discard()

# %% [raw]
# 3.What does list1.extend(list2) do?
#
# a) Adds list2 as a new element
# b) Merges list1 and list2
# c) Creates a tuple
# d) Reverses both lists

# %% [raw]
# 📝 Section B: Tuples:

# %% [raw]
# 4.Which of the following is a valid tuple?
#
# a) t = (1)
# b) t = [1, 2, 3]
# c) t = (1, 2, 3)
# d) t = {1, 2, 3}

# %% [raw]
# 5.What happens if you try to modify a tuple?
#
# a) It updates
# b) It appends
# c) It gives an error
# d) It deletes automatically

# %% [raw]
# 6.What is the output of this?
#
# t = (10, 20, 30)
# print(t[1])
#
# a) 10
# b) 20
# c) 30
# d) IndexError

# %% [raw]
# 📝 Section C: Dictionaries:

# %% [raw]
# 7.What does this code print?
#
# d = {"a": 1, "b": 2}
# print(d.get("c"))
#
# a) 0
# b) None
# c) Error
# d) c

# %% [raw]
# 8.Which method is used to get all keys in a dictionary?
#
# a) d.values()
# b) d.items()
# c) d.keys()
# d) d.getkeys()

# %% [raw]
# 9.What is a correct way to update the value of key "age"?
#
# person = {"name": "Ali", "age": 20}
#
# a) person.age = 21
# b) person["age"] = 21
# c) person.get("age") = 21
# d) person.update("age": 21)

# %% [raw]
# 📝 Section D: Sets:

# %% [raw]
# 10.Which of these removes duplicates?
#
# a) List
# b) Tuple
# c) Set
# d) Dictionary

# %% [raw]
# 11.What is the output?
#
# s = set([1, 2, 2, 3])
# print(len(s))
#
# a) 4
# b) 3
# c) 2
# d) Error

# %% [raw]
# 12.Which method adds an element to a set?
#
# a) append()
# b) add()
# c) extend()
# d) insert()

# %% [raw]
# ✅ Answers Key:

# %% [raw]
# 1.b
# 2.a
# 3.b
# 4.c
# 5.c
# 6.b
# 7.b
# 8.c
# 9.b
# 10.c
# 11.b
# 12.b

# %% [raw]
# 🧪 Python Data Types Quiz:

# %% [raw]
# Choose the correct answer for each question. Answers are given at the end.

# %% [raw]
# 🟡 Section A: Numbers (int, float):

# %% [raw]
# 1.What is the output of the following code?
#
# x = 5
# y = 2.5
# print(x + y)
#
# a) 7
# b) 7.5
# c) 52.5
# d) Error

# %% [raw]
# 2.Which function returns the data type of a variable?
#
# a) typeof()
# b) gettype()
# c) type()
# d) datatype()

# %% [raw]
# 🟢 Section B: Strings:

# %% [raw]
# 3.What will be the result of this?
#
# name = "Python"
# print(name[1:4])
#
# a) yth
# b) Pyt
# c) ytho
# d) ytho

# %% [raw]
# 4.Strings are:
#
# a) Mutable
# b) Immutable
# c) Sortable
# d) Numerical

# %% [raw]
# 🔵 Section C: Lists:

# %% [raw]
# 5.Which list method removes an element by value?
#
# a) pop()
# b) remove()
# c) delete()
# d) cut()

# %% [raw]
# 6.What is the result of:
#
# colors = ["red", "blue", "green"]
# print(colors[-1])
#
# a) red
# b) blue
# c) green
# d) Error

# %% [raw]
# 🔴 Section D: Tuples:

# %% [raw]
# 7.Tuples are different from lists because:
#
# a) They are slower
# b) They are unordered
# c) They are immutable
# d) They store strings only

# %% [raw]
# 8.What is the output?
#
# t = (10, 20, 30)
# print(len(t))
#
# a) 2
# b) 3
# c) 0
# d) Error

# %% [raw]
# 🟣 Section E: Dictionaries:

# %% [raw]
# 9.Which of these is a valid dictionary?
#
# a) {1, 2, 3}
# b) [1, "a", 3]
# c) {"name": "Ali", "age": 20}
# d) ("key", "value")

# %% [raw]
# 10.What will d.get("city") return if "city" is not in the dictionary?
#
# a) "city"
# b) None
# c) Error
# d) False

# %% [raw]
# 🟤 Section F: Sets:

# %% [raw]
# 11.Sets do not allow:
#
# a) Sorting
# b) Duplicates
# c) Strings
# d) Integers

# %% [raw]
# 12.What does this code print?
#
# s = set([1, 2, 2, 3])
# print(len(s))
#
# a) 4
# b) 3
# c) 2
# d) Error

# %% [raw]
# ✅ Answer Key:

# %% [raw]
# | Q  | Answer |
# | -- | ------ |
# | 1  | b      |
# | 2  | c      |
# | 3  | a      |
# | 4  | b      |
# | 5  | b      |
# | 6  | c      |
# | 7  | c      |
# | 8  | b      |
# | 9  | c      |
# | 10 | b      |
# | 11 | b      |
# | 12 | b      |

# %%
student = {"name": "Alice", "age": 22, "major": "Computer Science"}

# Get all keys
keys = student.keys()
print(keys)          
print(list(keys))    

# Usage in iteration
for key in student.keys():
    print(f"Key: {key}")
# Out:
# dict_keys(['name', 'age', 'major'])
# ['name', 'age', 'major']
# Key: name
# Key: age
# Key: major

# %%
# Get all values
values = student.values()
print(values)        
print(list(values))  

# Check if a value exists
print(22 in student.values())  # True
print("Math" in student.values())
# Out:
# dict_values(['Alice', 22, 'Computer Science'])
# ['Alice', 22, 'Computer Science']
# True
# False

# %%
# Get all items as tuples
items = student.items()
print(items)  

# Most common usage - iteration
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# dict_items([('name', 'Alice'), ('age', 22), ('major', 'Computer Science')])
# name: Alice
# age: 22
# major: Computer Science

# %%
# Safe way to access values
print(student.get("name"))     
print(student.get("gpa"))      
print(student.get("gpa", 3.8))  

# Compare with direct access
try:
    print(student["gpa"]) 
except KeyError:
    print("Key not found")
# Out:
# Alice
# None
# 3.8
# Key not found

# %%
# Update existing and add new keys
student.update({"age": 23, "gpa": 3.9, "minor": "Mathematics"})
print(student)

# Can also update with another dictionary
new_info = {"graduation_year": 2024, "age": 24}
student.update(new_info)
print(student["age"])
# Out:
# {'name': 'Alice', 'age': 23, 'major': 'Computer Science', 'gpa': 3.9, 'minor': 'Mathematics'}
# 24

# %%
# Remove and return a value
major = student.pop("major")
print(major)  
print(student)  

# With default value
phone = student.pop("phone", "N/A")
print(phone)  

# Without default (raises KeyError)
try:
    student.pop("nonexistent_key")
except KeyError as e:
    print(f"Error: {e}")
# Out:
# Computer Science
# {'name': 'Alice', 'age': 24, 'gpa': 3.9, 'minor': 'Mathematics', 'graduation_year': 2024}
# N/A
# Error: 'nonexistent_key'

# %%
# Clear all items
student.clear()
print(student) 

# Different from creating new dict
grades = {"math": 90, "science": 85}
ref = grades
grades.clear()
print(ref)  

grades = {"math": 90, "science": 85}
ref = grades
grades = {}  
print(ref)
# Out:
# {}
# {}
# {'math': 90, 'science': 85}

# %%
# Inventory management example
inventory = {"apples": 50, "bananas": 30, "oranges": 40}

# Update inventory
inventory.update({"apples": 45, "pears": 20}) 
# Remove out-of-stock item
if inventory.get("bananas", 0) <= 0:
    inventory.pop("bananas")

# Print current stock
print("Current Inventory:")
for item, quantity in inventory.items():
    print(f"- {item.capitalize()}: {quantity} units")

# Clear inventory at end of day
inventory.clear()
print("Inventory after clearance:", inventory)
# Out:
# Current Inventory:
# - Apples: 45 units
# - Bananas: 30 units
# - Oranges: 40 units
# - Pears: 20 units
# Inventory after clearance: {}

# %%
fruits = {"apple", "banana"}
fruits.add("orange")
print(fruits)  

# Adding a duplicate has no effect
fruits.add("apple")
print(fruits)
# Out:
# {'apple', 'banana', 'orange'}
# {'apple', 'banana', 'orange'}

# %%
numbers = {1, 2, 3, 4, 5}
numbers.remove(3)
print(numbers)  
# Trying to remove non-existent element raises KeyError
try:
    numbers.remove(10)
except KeyError:
    print("Element not found in set")
# Out:
# {1, 2, 4, 5}
# Element not found in set

# %%
letters = {"a", "b", "c", "d"}
popped = letters.pop()
print(f"Removed: {popped}, Remaining: {letters}")

# Popping from empty set raises KeyError
empty_set = set()
try:
    empty_set.pop()
except KeyError:
    print("Cannot pop from empty set")
# Out:
# Removed: d, Remaining: {'c', 'b', 'a'}
# Cannot pop from empty set

# %%
primes = {2, 3, 5, 7, 11}
primes.clear()
print(primes)  # set()
# Out:
# set()

# %%
# Blog post tagging system
post1_tags = {"tech", "python", "web"}
post2_tags = {"python", "data", "ai"}

# Add a new tag
post1_tags.add("programming")

# Remove a tag safely
post2_tags.discard("data-science")  # No error if doesn't exist

# Find common tags
common_tags = post1_tags.intersection(post2_tags)
print(f"Common tags: {common_tags}")  # {'python'}

# Get unique tags from both posts
all_tags = post1_tags.union(post2_tags)
print(f"All unique tags: {all_tags}")

# Tags only in post1
post1_unique = post1_tags.difference(post2_tags)
print(f"Post1 unique tags: {post1_unique}")
# Out:
# Common tags: {'python'}
# All unique tags: {'programming', 'web', 'python', 'ai', 'tech', 'data'}
# Post1 unique tags: {'tech', 'programming', 'web'}
