# %% [raw]
# 🔷 1. Dictionaries in Python

# %% [raw]
# 📘 What is a Dictionary?
#  >A dictionary is a collection of key-value pairs.

# %%
student = {
    "name": "Alice",
    "age": 20,
    "course": "Python"
}
print(student)
# Out:
# {'name': 'Alice', 'age': 20, 'course': 'Python'}

# %% [raw]
# 🔑 Properties of a Dictionary:

# %% [raw]
# | Property                          | Description                                  |
# | --------------------------------- | -------------------------------------------- |
# | Unordered (before Python 3.7)     | Items are not stored in a fixed order        |
# | Mutable                           | ✅ Yes – can change, add, or remove items   |
# | Key must be unique                | Duplicate keys are not allowed               |
# | Values can be any type            | ✅ Allowed (string, int, list, etc.)         |
# | Defined with `{}`                 | Curly braces are used to create a dictionary |

# %% [raw]
# 🛠️ Common Dictionary Methods:

# %% [raw]
# | Method               | Description                                 | Example                       |
# | -------------------- | ------------------------------------------- | ----------------------------- |
# | `dict.keys()`        | Returns all keys                            | `student.keys()`              |
# | `dict.values()`      | Returns all values                          | `student.values()`            |
# | `dict.items()`       | Returns key-value pairs                     | `student.items()`             |
# | `dict.get(key)`      | Returns value of key or `None` if not found | `student.get("age")`          |
# | `dict.update({...})` | Updates with new key-value pairs            | `student.update({"age": 21})` |
# | `dict.pop(key)`      | Removes item with specified key             | `student.pop("course")`       |
# | `dict.clear()`       | Removes all items                           | `student.clear()`             |

# %% [raw]
# ✅ Example:

# %%
student = {"name": "Bob", "age": 22}
print(student["name"])         
student["age"] = 23            
student["gender"] = "Male"    
print(student.get("course"))
# Out:
# Bob
# None

# %% [raw]
# 🔶 2. Sets in Python:

# %% [raw]
# 📘 What is a Set?
#  >A set is a collection of unique and unordered items.

# %%
my_set = {1, 2, 3, 4}
print(my_set)
# Out:
# {1, 2, 3, 4}

# %% [raw]
# 🔑 Properties of a Set:

# %% [raw]
# | Property            | Description                               |
# | --------------------| ----------------------------------------- |
# | Unordered           | No index, items may appear in any order   |
# | Mutable             | ✅ Yes – can add or remove items         |
# | Unique values only  | ❌ No duplicates allowed                 |
# | No indexing/slicing | You can’t access items by index           |
# | Defined with `{}`   | Curly braces used, just like dictionaries |

# %% [raw]
# ⚠️ Note:
#  >{} creates an empty dictionary, not a set. Use set() to create an empty set.

# %% [raw]
# 🛠️ Common Set Methods:

# %% [raw]
# | Method                   | Description                                  | Example               |
# | ------------------------ | -------------------------------------------- | --------------------- |
# | `set.add(x)`             | Adds element `x`                             | `my_set.add(5)`       |
# | `set.remove(x)`          | Removes element `x`, raises error if missing | `my_set.remove(2)`    |
# | `set.discard(x)`         | Removes element `x`, no error if missing     | `my_set.discard(100)` |
# | `set.pop()`              | Removes a random item                        | `my_set.pop()`        |
# | `set.clear()`            | Removes all elements                         | `my_set.clear()`      |
# | `set.union(set2)`        | Combines two sets                            | `a.union(b)`          |
# | `set.intersection(set2)` | Common elements                              | `a.intersection(b)`   |
# | `set.difference(set2)`   | Elements in first set but not in second      | `a.difference(b)`     |

# %% [raw]
# ✅ Example:

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print(a.union(b))         
print(a.intersection(b)) 
print(a.difference(b))    

a.add(6)                 
a.remove(2)
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %% [raw]
# 🧠 Summary Table

# %% [raw]
# | Feature        | Dictionary          | Set                         |
# | ---------------| ------------------- | --------------------------- |
# | Type           | Key-value pairs     | Unique values               |
# | Mutable        | ✅ Yes              | ✅ Yes                     |
# | Duplicates     | Keys must be unique | All elements must be unique |
# | Indexed?       | ✅ Yes (by key)     | ❌ No                      |
# | Empty creation | `{}` (dictionary)   | `set()`                     |
