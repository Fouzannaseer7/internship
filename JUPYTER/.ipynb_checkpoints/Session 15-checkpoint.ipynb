# %% [raw]
# Python Lambda, Map, Filter, Reduce & Enumerate:

# %% [raw]
# These are powerful functional programming tools in Python that help you write concise, efficient code. Let's break them down with simple examples.

# %% [raw]
# 1. Lambda Functions (Anonymous Functions):
#  >Lambda functions are small, anonymous functions defined with the lambda keyword.

# %% [raw]
# Basic Syntax:

# %% [markdown]
# lambda arguments: expression

# %% [raw]
# Examples:

# %%
# Regular function
def square(x):
    return x ** 2

# Equivalent lambda
square = lambda x: x ** 2
print(square(5))  # 25

# Using lambda directly
print((lambda x, y: x + y)(3, 4))  # 7
# Out:
# 25
# 7

# %% [raw]
# When to Use:
#  //For simple one-line operations
#  //When you need a function temporarily
#  //As arguments to higher-order functions (like map/filter)

# %% [raw]
# 2. map() - Apply Function to All Items:
#  >Applies a function to every item in an iterable (list, tuple, etc.)

# %% [raw]
# Syntax:

# %% [markdown]
# map(function, iterable)

# %% [raw]
# Examples:

# %%
numbers = [1, 2, 3, 4]

# Using lambda
squared = map(lambda x: x**2, numbers)
print(list(squared))  # [1, 4, 9, 16]

# Equivalent list comprehension
squared = [x**2 for x in numbers]
# Out:
# [1, 4, 9, 16]

# %% [raw]
# 3. filter() - Select Items Based on Condition:
#  >Filters elements where the function returns True.

# %% [raw]
# Syntax:

# %% [markdown]
# filter(function, iterable)

# %% [raw]
# Examples:

# %%
numbers = [1, 2, 3, 4, 5, 6]

# Get even numbers
evens = filter(lambda x: x % 2 == 0, numbers)
print(list(evens))  # [2, 4, 6]

# Equivalent list comprehension
evens = [x for x in numbers if x % 2 == 0]
# Out:
# [2, 4, 6]

# %% [raw]
# 4. reduce() - Cumulative Operation:
#  >Applies a function cumulatively to items (from functools module).

# %% [raw]
# Syntax:

# %% [markdown]
# from functools import reduce
# reduce(function, iterable[, initializer])

# %% [raw]
# Examples:

# %%
from functools import reduce

numbers = [1, 2, 3, 4]

# Sum of numbers
sum = reduce(lambda x, y: x + y, numbers)
print(sum)  # 10

# Find maximum
max_num = reduce(lambda x, y: x if x > y else y, numbers)
print(max_num)  # 4
# Out:
# 10
# 4

# %% [raw]
# 5. enumerate() - Get Index with Value:
#  >Adds a counter to an iterable.

# %% [raw]
# Syntax:

# %% [markdown]
# enumerate(iterable, start=0)

# %% [raw]
# Examples:

# %%
fruits = ['apple', 'banana', 'cherry']

# Without enumerate
for i in range(len(fruits)):
    print(i, fruits[i])

# With enumerate (better!)
for index, fruit in enumerate(fruits):
    print(index, fruit)

# With custom start index
for index, fruit in enumerate(fruits, start=1):
    print(index, fruit)
# Out:
# 0 apple
# 1 banana
# 2 cherry
# 0 apple
# 1 banana
# 2 cherry
# 1 apple
# 2 banana
# 3 cherry

# %% [raw]
# Practical Examples:

# %% [raw]
# 1. Processing User Data:

# %%
users = ['Alice', 'Bob', 'Charlie']

# Add "User_" prefix and number
processed = list(map(lambda x: f"User_{x[0]}_{x[1]}", enumerate(users, 1)))
print(processed)  # ['User_1_Alice', 'User_2_Bob', 'User_3_Charlie']
# Out:
# ['User_1_Alice', 'User_2_Bob', 'User_3_Charlie']

# %% [raw]
# 2. Analyzing Numbers:

# %%
numbers = [12, 15, 20, 8, 31]

# Get numbers divisible by 5 and square them
result = list(map(lambda x: x**2, filter(lambda x: x % 5 == 0, numbers)))
print(result)  # [225, 400, 25]
# Out:
# [225, 400]

# %% [raw]
# 3. Word Processing:

# %%
words = ["python", "map", "filter", "reduce"]

# Create dictionary with word lengths
word_dict = {word: len(word) for word in words}
print(word_dict)

# Using enumerate and map
word_dict = dict(map(lambda x: (x[1], len(x[1])), enumerate(words)))
# Out:
# {'python': 6, 'map': 3, 'filter': 6, 'reduce': 6}

# %% [raw]
# Key Differences:

# %% [raw]
# Function	         Purpose	                 Returns	  Import Needed?
# lambda	     Create small anonymous functions	Function	       No
# map()	     Apply function to all items	    Iterator	       No
# filter()	 Select items based on condition	Iterator	       No
# reduce()	 Apply cumulative operation	        Single value	   Yes (functools)
# enumerate()	 Add counter to iterable	        Enumerate object   No

# %% [raw]
# When to Use What:

# %% [raw]
# >Lambda: Simple one-time operations
# >map: Transform all items in a collection
# >filter: Select specific items from a collection
# >reduce: Combine all items (sum, max, etc.)
# >enumerate: Need index while looping

# %% [raw]
# Python Functions Quiz :

# %% [raw]
# 1.What's the correct way to define and call a function that greets a user by name?

# %% [raw]
# a) def greet_user(name):
#        print(f"Hello, {name}!")
#    greet_user("Alice")
#
# b) function greet_user(name):
#        print("Hello, " + name)
#    call greet_user("Alice")
#
# c) greet_user(name):
#        return "Hello, " + name
#    greet_user("Alice")

# %% [raw]
# Answer:

# %%
# Correct answer is a)
def greet_user(name):
    print(f"Hello, {name}!")
greet_user("Alice")
# Out:
# Hello, Alice!

# %% [raw]
# 2.What does this function output?

# %% [raw]
# def calculate(a, b=2):
#     return a * b + a
#
# print(calculate(3))
# print(calculate(4, 1))

# %% [raw]
# Answer:

# %% [raw]
# First call uses default b=2: 3 * 2 + 3 = 9
# Second call overrides default: 4 * 1 + 4 = 8

# %% [raw]
# 9
# 8

# %% [raw]
# 3.Fix this function to return both area and circumference of a circle:

# %% [raw]
# def circle_stats(r):
#     area = 3.14 * r ** 2
#     circumference = 2 * 3.14 * r
#     # What's missing?

# %% [raw]
# Answer:

# %%
def circle_stats(r):
    area = 3.14 * r ** 2
    circumference = 2 * 3.14 * r
    return area, circumference  # Return both values

a, c = circle_stats(5)
print(f"Area: {a}, Circumference: {c}")
# Out:
# Area: 78.5, Circumference: 31.400000000000002

# %% [markdown]
# 4.What's the output of this lambda/map/filter combination?

# %% [raw]
# numbers = [1, 2, 3, 4, 5]
# result = list(map(lambda x: x+10, filter(lambda x: x%2==0, numbers)))
# print(result)

# %% [raw]
# Answer:

# %% [raw]
# filter keeps even numbers: [2, 4]
# map adds 10 to each: [12, 14]
#
# Output: [12, 14]

# %% [raw]
# 5.What keyword is used to define a function in Python?
# a) func
# b) define
# c) def
# d) function

# %% [raw]
# Answer:

# %% [raw]
# b) Hello!

# %% [raw]
# 6.What will be the output of the following code?

# %% [raw]
# def greet():
#     print("Hello!")
#
# greet()

# %% [raw]
# a) Nothing
# b) Hello!
# c) greet()
# d) Error

# %% [raw]
# Answer:

# %% [raw]
# d)error

# %% [raw]
# 7.How do you pass information to a function?
# a) Using parameters
# b) Using arguments
# c) Using return statements
# d) Both a and b

# %% [raw]
# Answer:

# %% [raw]
# d) Both a and b

# %% [raw]
# 8.What is the output of this code?

# %% [raw]
# def add(a, b=2):
#     return a + b
#
# print(add(3))

# %% [raw]
# a) 5
# b) 3
# c) Error
# d) None

# %% [raw]
# Answer:

# %% [raw]
# a) 5

# %% [raw]
# True or False:

# %% [raw]
# 9.A function must always have a return statement. (True/False)

# %% [raw]
# False

# %% [raw]
# 10.Function parameters and arguments are the same thing. (True/False)

# %% [raw]
# False (parameters are in the definition, arguments are the values passed)

# %% [raw]
# 11.You can call a function inside another function. (True/False)

# %% [raw]
# True

# %% [raw]
# 12.A function can have multiple return statements. (True/False)

# %% [raw]
# True

# %% [raw]
# 13.Python functions can return multiple values. (True/False)

# %% [raw]
# True (as a tuple)

# %% [raw]
# Fill in the Blanks:

# %% [raw]
# 14.The values passed to a function when it is called are called _______.

# %% [raw]
# arguments

# %% [raw]
# 15.Variables declared inside a function have _______ scope.

# %% [raw]
# local

# %% [raw]
# 16.To make a function return no value, you can either omit the return statement or use _______.

# %% [raw]
# return None

# %% [raw]
# 17.The _______ keyword allows a function to accept any number of positional arguments.

# %% [raw]
# *args

# %% [raw]
# 18.A _______ function calls itself.

# %% [raw]
# recursive
