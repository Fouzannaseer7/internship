# %% [raw]
# 🔷 1. What are Lists and Tuples?

# %% [raw]
# ✅ List:
#  >A list is a collection of ordered items which can be changed (mutable).
#  >You can store any type of data: numbers, strings, other lists, etc.

# %% [raw]
# my_list = [10, "apple", 3.14]

# %% [raw]
# ✅ Tuple:
#  >A tuple is also an ordered collection, but it's unchangeable (immutable) after creation.

# %% [raw]
# my_tuple = (10, "apple", 3.14)

# %% [raw]
# 🔷 2. Properties:

# %% [raw]
# | Property                 | List                          | Tuple                     |
# | -------------------------| ------------------------------| ------------------------- |
# | Mutable                  | ✅ Yes – items can be changed | ❌ No – cannot be changed|
# | Ordered                  | ✅ Yes                        | ✅ Yes                   |
# | Allows duplicates**      | ✅ Yes                        | ✅ Yes                   |
# | Can store multiple types | ✅ Yes                        | ✅ Yes                   |
# | Syntax                   | Square brackets: `[]`          | Round brackets: `()`     |

# %% [raw]
# 🔷 3. Indexing:
#  >Both lists and tuples support indexing – it means accessing elements by their position.
#  >Python uses 0-based indexing:
#   //First item → index 0
#   //Second item → index 1
#   //And so on...

# %%
my_list = [100, 200, 300]
print(my_list[0])  

my_tuple = ("a", "b", "c")
print(my_tuple[1])
# Out:
# 100
# b

# %% [raw]
# 🧭 Negative Indexing:
# >-1 refers to the last element
#
# >-2 to the second last, and so on.

# %%
print(my_list[-1])
# Out:
# 300

# %% [raw]
# 🔷 4. Slicing:
#  >Slicing means getting a part of the list or tuple.
#  >Syntax: sequence[start:stop:step]
#   //start – index to start from (inclusive)
#   //stop – index to stop at (exclusive)
#   //step – how many items to skip

# %%
my_list = [10, 20, 30, 40, 50]

print(my_list[1:4])    
print(my_list[:3])    
print(my_list[::2])   
print(my_list[::-1])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [10, 30, 50]
# [50, 40, 30, 20, 10]

# %% [raw]
# Tuples work the same way as lists when slicing.

# %% [raw]
# 🔷 5. List Methods (Most Common):

# %% [raw]
# ➕ append(item):
#  >Adds an item to the end.

# %%
my_list.append(60)
print(my_list)
# Out:
# [10, 20, 30, 40, 50, 60]

# %% [raw]
# 📍 insert(index, item):
#  >Inserts item at a specific position.

# %%
my_list.insert(2, 25) 
print(my_list)
# Out:
# [10, 20, 25, 25, 30, 40, 50, 60]

# %% [raw]
# ❌ remove(item):
#  >Removes the first occurrence of the item.

# %%
my_list.remove(20)
print(my_list)
# Out:
# [10, 25, 25, 30, 40, 50, 60]

# %% [raw]
# 🔄 pop():
#  >Removes and returns the last item (or item at a given index).

# %%
my_list.pop()      
my_list.pop(1)      
print(my_list)
# Out:
# [10, 25, 30, 40, 50]

# %% [raw]
# 🔃 reverse() and sort():

# %%
my_list.reverse()     
my_list.sort()   
print(my_list)
# Out:
# [10, 25, 30, 40, 50]

# %% [raw]
# 🔷 Tuple Methods:
#  >Since tuples are immutable, they only have 2 methods:

# %% [raw]
# 📌 count(item):
#  >Counts how many times an item appears.

# %%
my_tuple = (1, 2, 2, 3)
print(my_tuple.count(2))
# Out:
# 2

# %% [raw]
# 📍 index(item):
#  >Finds the index of the first occurrence.

# %%
print(my_tuple.index(3))
# Out:
# 3

# %% [raw]
# 🔷 6. List Comprehension:
#  >This is a shortcut for creating new lists in one line.

# %% [raw]
# 🧠 Format:

# %% [raw]
# new_list = [expression for item in iterable if condition]

# %% [raw]
# ✅ Examples:

# %%
squares = [x**2 for x in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %% [raw]
# 🟡 Tuple Comprehension:
#  >Not directly supported, but you can convert a generator to tuple:

# %%
tup = tuple(x**2 for x in range(5))
print(tup)
# Out:
# (0, 1, 4, 9, 16)

# %% [raw]
# ✅ Summary Table

# %% [raw]
# | Feature       | List                         | Tuple                         |
# | ------------- | -----------------------------| ------------------------------|
# | Syntax        | `[]`                         | `()`                          |
# | Mutable       | ✅ Yes                       |  ❌ No                       |
# | Indexing      | ✅ Supported                 | ✅ Supported                 |
# | Slicing       | ✅ Yes                       | ✅ Yes                       |
# | Methods       | Many (append, remove, sort)   | Few (count, index)           |
# | Comprehension | ✅ List comprehension        | ✅ Using generator + tuple() |
