# %% [raw]
# Loops and control statements:

# %% [raw]
# 1. What Are Loops?
#  >Loops help you repeat a block of code multiple times without writing the same code
#   again and again.

# %% [raw]
# Types of Loops in Python:

# %% [raw]
# A. for Loop:
#  >Used when you know how many times you want to repeat something.
#  >Works with lists, strings, ranges, etc.

# %% [raw]
# Syntax:
#  >for variable in sequence:
#     # Code to repeat

# %% [raw]
# Example 1: Looping Through a List

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %% [raw]
# Here, fruit takes each value from fruits one by one.

# %% [raw]
# Example 2: Looping with range()

# %%
for i in range(3):  # 0, 1, 2
    print(i)
# Out:
# 0
# 1
# 2

# %% [raw]
# range(3) generates numbers from 0 to 2.

# %% [raw]
# B. while Loop:
#  >Used when you don’t know how many times to repeat but want to loop until a condition
#   is False.

# %% [raw]
# Syntax:
#   >while condition:
#     # Code to repeat

# %% [raw]
# Example:

# %%
count = 0
while count < 3:
    print(count)
    count += 1  # Same as count = count + 1
# Out:
# 0
# 1
# 2

# %% [raw]
# >The loop runs as long as count < 3 is True.
# >⚠️ Danger! If the condition never becomes False, it becomes an infinite loop!

# %% [raw]
# 2. What Are Control Statements?
#  >Control statements help you make decisions and control the flow of your program.

# %% [raw]
# A. if, elif, else (Decision Making):
#  >Used to run different code blocks based on conditions.

# %% [raw]
# Syntax:
#  >if condition1:
#      # Runs if condition1 is True
#  >elif condition2:
#      # Runs if condition2 is True (optional)
#  >else:
#      # Runs if all conditions are False (optional)

# %% [raw]
# Example:

# %%
age = 18
if age < 13:
    print("Child")
elif age < 20:
    print("Teenager")
else:
    print("Adult")
# Out:
# Teenager

# %% [raw]
# >Checks conditions one by one and executes the first matching block.

# %% [raw]
# Summary Table:

# %% [raw]
# Concept         	What It Does	                           Example
# for loop	    Repeats for each item in a sequence	   for i in [1, 2, 3]: print(i)
# while loop	    Repeats while a condition is True	   while x < 5: print(x); x += 1
# if-elif-else	Makes decisions based on conditions	   if age > 18: print("Adult")
